# %%
pip install stable-baselines3==2.3.2
# Out:
# Requirement already satisfied: stable-baselines3==2.3.2 in d:\anaconda\lib\site-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (1.23.5)
# Requirement already satisfied: torch>=1.13 in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (2.0.1)
# Requirement already satisfied: cloudpickle in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (2.0.0)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (1.5.3)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from stable-baselines3==2.3.2) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\anaconda\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.3.2) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\anaconda\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.3.2) (0.0.4)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.9.0)
# Requirement already satisfied: sympy in d:\anaconda\lib\site-packages (from torch>=1.13->stable-baselines3==2.3.2) (1.11.1)
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from torch>=1.13->stable-baselines3==2.3.2) (2.8.4)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->stable-baselines3==2.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->stable-baselines3==2.3.2) (2022.7)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib->stable-baselines3==2.3.2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch>=1.13->stable-baselines3==2.3.2) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda\lib\site-packages (from sympy->torch>=1.13->stable-baselines3==2.3.2) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium==0.29.1
# Out:
# Collecting gymnasium==0.29.1
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\lib\site-packages (from gymnasium==0.29.1) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\anaconda\lib\site-packages (from gymnasium==0.29.1) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\anaconda\lib\site-packages (from gymnasium==0.29.1) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\anaconda\lib\site-packages (from gymnasium==0.29.1) (0.0.4)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0a2
#     Uninstalling gymnasium-1.0.0a2:
#       Successfully uninstalled gymnasium-1.0.0a2
# Successfully installed gymnasium-0.29.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shimmy 2.0.0 requires gymnasium>=1.0.0a1, but you have gymnasium 0.29.1 which is incompatible.

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %%
#log_path = os.path.join('Training', 'Logs')
#log_path

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
            
         # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env=ShowerEnv()
# Out:
# D:\Anaconda\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.observation_space.sample()
# Out:
# array([89.18825], dtype=float32)

# %%
env.reset()
# Out:
# array([40.])

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-44
# Episode:2 Score:-40
# Episode:3 Score:-48
# Episode:4 Score:-34
# Episode:5 Score:-12

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# D:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=400000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -29.6    |
# | time/              |          |
# |    fps             | 1036     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008863915 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000338   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 53.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.6       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012286643 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000842    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 54.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.4        |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0062244246 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00041      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 61.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -31.7       |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009942384 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000463   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000418   |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -30.2         |
# | time/                   |               |
# |    fps                  | 874           |
# |    iterations           | 6             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00066884037 |
# |    clip_fraction        | 0.0141        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 6.64e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 38.4          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.00012       |
# |    value_loss           | 61.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.6        |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0038163892 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -5.14e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.000168     |
# |    value_loss           | 74.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.7       |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009558724 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.01e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 74.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.5       |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010203394 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.92e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 71.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.2        |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033121903 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000101    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 63.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26         |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 11          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008607771 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000655   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00991    |
# |    value_loss           | 75.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -21.2        |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 12           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0059333793 |
# |    clip_fraction        | 0.00981      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000105    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 81.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.5       |
# | time/                   |             |
# |    fps                  | 903         |
# |    iterations           | 13          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010172448 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 74.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.8        |
# | time/                   |              |
# |    fps                  | 902          |
# |    iterations           | 14           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0073406994 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00325      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 66.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -18.7      |
# | time/                   |            |
# |    fps                  | 895        |
# |    iterations           | 15         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01406475 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.0171     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.8       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0096    |
# |    value_loss           | 64.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -18          |
# | time/                   |              |
# |    fps                  | 896          |
# |    iterations           | 16           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033154362 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.031        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 70.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -15.2        |
# | time/                   |              |
# |    fps                  | 894          |
# |    iterations           | 17           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0050587896 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0284      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.6         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 70.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 18           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0069512445 |
# |    clip_fraction        | 0.0767       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.0011       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.2         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00502     |
# |    value_loss           | 56.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -17.9        |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 19           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0090197325 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.0251      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.6         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 59           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -17.8       |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 20          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009350451 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 5.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 71          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -7.58       |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 21          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010273712 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.00179     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -7.22       |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 22          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008418302 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.044      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 42.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 0.34         |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 23           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0104987435 |
# |    clip_fraction        | 0.192        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00196     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0195      |
# |    value_loss           | 57.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 2.76        |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 24          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008545455 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 8.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 893         |
# |    iterations           | 25          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011282062 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.000965   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 37.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 26          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009848652 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.000104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 27          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010072876 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00225    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 35.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 28          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010652702 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.000211   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 886         |
# |    iterations           | 29          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014988363 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.99e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00145     |
# |    value_loss           | 38.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 30          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013158269 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.000258    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 43.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 31          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011057062 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.000288    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 32          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012574714 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00021     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 38.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 27.9       |
# | time/                   |            |
# |    fps                  | 888        |
# |    iterations           | 33         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02227145 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.000538   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.8       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0191    |
# |    value_loss           | 47.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.9        |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 34          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008758658 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.00128     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00102     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 35          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012789354 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | -0.000117   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0051      |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 36          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013604797 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 7.46e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000172   |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 37          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.021949286 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 38          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020640023 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 2.03e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00806     |
# |    value_loss           | 71.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 39          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014134959 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 7.21e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00141     |
# |    value_loss           | 64.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44          |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 40          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010213895 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 1.62e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00345     |
# |    value_loss           | 76.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.8        |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 41          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.027076688 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 8.05e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46          |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 76.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.4        |
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 42          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006652503 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 3.87e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00714     |
# |    value_loss           | 77          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 43          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015961684 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 81.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.4        |
# | time/                   |             |
# |    fps                  | 876         |
# |    iterations           | 44          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018619988 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | -4.17e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00928     |
# |    value_loss           | 93.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.4        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 45          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009132478 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | -3.46e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00255     |
# |    value_loss           | 80.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.1        |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 46          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006419705 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00801     |
# |    value_loss           | 84.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48         |
# | time/                   |            |
# |    fps                  | 879        |
# |    iterations           | 47         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01667922 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.928     |
# |    explained_variance   | -5.48e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.2       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0101     |
# |    value_loss           | 81.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 48          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018170396 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 4.83e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00456     |
# |    value_loss           | 87.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 49          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013246169 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | -4.53e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.4        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 95.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 50          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016205015 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.6        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00878     |
# |    value_loss           | 89.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 51          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.012958738 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 2.03e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.1        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00923     |
# |    value_loss           | 93.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47          |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 52          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.014935142 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 1.19e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50          |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00738     |
# |    value_loss           | 97.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 53          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010221967 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 3.7e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0021      |
# |    value_loss           | 85.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.5        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 54          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.018407263 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 3.73e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.1        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00436     |
# |    value_loss           | 78.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.5        |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 55          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.026001692 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.000257    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.6        |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56          |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 179         |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.008128272 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | -5.6e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.6        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.00795     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.6        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 180         |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.005239415 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 3.99e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.1        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00542     |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.9         |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 181          |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0129429735 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 1.73e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.2         |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | 0.0114       |
# |    value_loss           | 116          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 57.1       |
# | time/                   |            |
# |    fps                  | 851        |
# |    iterations           | 182        |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.01955102 |
# |    clip_fraction        | 0.0991     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.462     |
# |    explained_variance   | -0.000108  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.1       |
# |    n_updates            | 1810       |
# |    policy_gradient_loss | 0.0065     |
# |    value_loss           | 115        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 183         |
# |    time_elapsed         | 440         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.010067275 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 5.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.5        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00925     |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.5        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 184         |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.010570354 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | -2.24e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.6        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00988     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 185         |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.008638714 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 6.5e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.6        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.00877     |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.8         |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 186          |
# |    time_elapsed         | 448          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0072548855 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | -1.22e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.9         |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | 0.00733      |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 187         |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.008755021 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | -6.2e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.1        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00728     |
# |    value_loss           | 118         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.7         |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 188          |
# |    time_elapsed         | 452          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0031105739 |
# |    clip_fraction        | 0.0999       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.1         |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | 0.00898      |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 189         |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.006643426 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 3.34e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.4        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.00727     |
# |    value_loss           | 118         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.4         |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 190          |
# |    time_elapsed         | 457          |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0081694145 |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 3.58e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.3         |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | 0.00804      |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 191         |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.008950055 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.2        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0156      |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.7         |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 192          |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0053414637 |
# |    clip_fraction        | 0.0932       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | -5.25e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.7         |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.00806      |
# |    value_loss           | 116          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 55.4         |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 193          |
# |    time_elapsed         | 465          |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0066155577 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.2         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | 0.00801      |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.2        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 194         |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.017239602 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.1        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 113         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 55.3       |
# | time/                   |            |
# |    fps                  | 849        |
# |    iterations           | 195        |
# |    time_elapsed         | 470        |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.00960709 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.595     |
# |    explained_variance   | -5.84e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 64.9       |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | 0.00461    |
# |    value_loss           | 116        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.3        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 196         |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.011793114 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.1        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0104      |
# |    value_loss           | 118         |
# -----------------------------------------

# %%
model.save('PPO')

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# D:\Anaconda\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (11.8, 58.62729739634943)
